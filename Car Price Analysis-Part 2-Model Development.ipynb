# %% [markdown]
# <div class="alert alert-block alert-info" style="margin-top: 20px">
# <h1 align=center><font size = 10>Car Price Data Analysis with Python Part 2</font></h1>

# %% [markdown]
# <h1 align=center><font size=6>Module 4: Model Development</font></h1>

# %% [markdown]
# <p>In this section, we will develop several models that will predict the price of the car using the variables or features. This is just an estimate but should give us an objective idea of how much the car should cost.</p>

# %% [markdown]
# Some questions we want to ask in this module
# <ul>
#     <li>do I know if the dealer is offering fair value for my trade-in?</li>
#     <li>do I know if I put a fair value on my car?</li>
# </ul>
# <p>Data Analytics, we often use <b>Model Development</b> to help us predict future observations from the data we have.</p>
#
# <p>A Model will help us understand the exact relationship between different variables and how these variables are used to predict the result.</p>

# %% [markdown]
# <h4>Setup</h4>

# %%
# Import libraries
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# load data and store in dataframe df:

# %%
# Path of data 
df = pd.read_csv(r"C:\Users\TrinhQuynh\DA_Learning\Python\Python project practice\Automobile.csv", index_col=0)
df
# Out:
#      symboling  normalized-losses         make num-of-doors   body-style  \
# 0            3              122.0  alfa-romero          two  convertible
# 1            3              122.0  alfa-romero          two  convertible
# 2            1              122.0  alfa-romero          two    hatchback
# 3            2              164.0         audi         four        sedan
# 4            2              164.0         audi         four        sedan
# ..         ...                ...          ...          ...          ...
# 196         -1               95.0        volvo         four        sedan
# 197         -1               95.0        volvo         four        sedan
# 198         -1               95.0        volvo         four        sedan
# 199         -1               95.0        volvo         four        sedan
# 200         -1               95.0        volvo         four        sedan
#
#     drive-wheels engine-location  wheel-base    length     width  ...  \
# 0            rwd           front        88.6  0.811148  0.890278  ...
# 1            rwd           front        88.6  0.811148  0.890278  ...
# 2            rwd           front        94.5  0.822681  0.909722  ...
# 3            fwd           front        99.8  0.848630  0.919444  ...
# 4            4wd           front        99.4  0.848630  0.922222  ...
# ..           ...             ...         ...       ...       ...  ...
# 196          rwd           front       109.1  0.907256  0.956944  ...
# 197          rwd           front       109.1  0.907256  0.955556  ...
# 198          rwd           front       109.1  0.907256  0.956944  ...
# 199          rwd           front       109.1  0.907256  0.956944  ...
# 200          rwd           front       109.1  0.907256  0.956944  ...
#
#      city-mpg  highway-mpg    price City-L/100km  highway-L/100km  \
# 0          21           27  13495.0    11.190476         8.703704
# 1          21           27  16500.0    11.190476         8.703704
# 2          19           26  16500.0    12.368421         9.038462
# 3          24           30  13950.0     9.791667         7.833333
# 4          18           22  17450.0    13.055556        10.681818
# ..        ...          ...      ...          ...              ...
# 196        23           28  16845.0    10.217391         8.392857
# 197        19           25  19045.0    12.368421         9.400000
# 198        18           23  21485.0    13.055556        10.217391
# 199        26           27  22470.0     9.038462         8.703704
# 200        19           25  22625.0    12.368421         9.400000
#
#     horsepower-binned  fuel-type_diesel  fuel-type_gas  aspiration_std  \
# 0                 Low                 0              1               1
# 1                 Low                 0              1               1
# 2              Medium                 0              1               1
# 3                 Low                 0              1               1
# 4                 Low                 0              1               1
# ..                ...               ...            ...             ...
# 196               Low                 0              1               1
# 197            Medium                 0              1               0
# 198            Medium                 0              1               1
# 199               Low                 1              0               0
# 200               Low                 0              1               0
#
#      aspiration_turbo
# 0                   0
# 1                   0
# 2                   0
# 3                   0
# 4                   0
# ..                ...
# 196                 0
# 197                 1
# 198                 0
# 199                 1
# 200                 1
#
# [201 rows x 31 columns]

# %% [markdown]
# <h2>1. Linear Regression</h4>

# %% [markdown]
# <p>One example of a Data  Model that we will be using is</p>
# <b>Simple Linear Regression</b>.
#
# <br>
# <p>Simple Linear Regression is a method to help us understand the relationship between two variables:</p>
# <ul>
#     <li>The predictor/independent variable (X)</li>
#     <li>The response/dependent variable (that we want to predict)(Y)</li>
# </ul>
#
# <p>The result of Linear Regression is a <b>linear function</b> that predicts the response (dependent) variable as a function of the predictor (independent) variable.</p>

# %% [markdown]
# $$
#  Y: Response \ Variable\\
#  X: Predictor \ Variables
# $$

# %% [markdown]
#  <b>Linear function:</b>
# $$
# Yhat = a + b  X
# $$

# %% [markdown]
# <ul>
#     <li>a refers to the <b>intercept</b> of the regression line0, in other words: the value of Y when X is 0</li>
#     <li>b refers to the <b>slope</b> of the regression line, in other words: the value with which Y changes when X increases by 1 unit</li>
# </ul>

# %% [markdown]
# <h4>Lets load the modules for linear regression</h4>

# %%
# Code:
from sklearn.linear_model import LinearRegression

# %% [markdown]
# <h4>Create the linear regression object</h4>

# %%
# Code:
lm = LinearRegression()

# %% [markdown]
# <h3>a. How could Highway-mpg help us predict car price?</h4>

# %% [markdown]
# For this example, we want to look at how highway-mpg can help us predict car price.
# Using simple linear regression, we will create a linear function with "highway-mpg" as the predictor variable and the "price" as the response variable.

# %% [markdown]
# <h4> Determine X1 = 'highway-mpg' , Y = 'price'

# %%
# Code:
X1 = df[["highway-mpg"]]
Y = df[['price']]

# %% [markdown]
# <h4> Fit the linear model using highway-mpg.

# %%
#Code
lm.fit(X1,Y)
# Out:
# LinearRegression()

# %% [markdown]
#  <h4>We can output a prediction

# %%
# Code:
Y1hat = lm.predict(X1)
Y1hat[:5]
# Out:
# array([[16236.50464347],
#        [16236.50464347],
#        [17058.23802179],
#        [13771.3045085 ],
#        [20345.17153508]])

# %% [markdown]
# <h4>What is the value of the intercept (a)?</h4>

# %%
# Code:
a1 = lm.intercept_
a1
# Out:
# array([38423.30585816])

# %% [markdown]
# <h4>What is the value of the Slope (b)?</h4>

# %%
# Code:
b1 = lm.coef_
b1
# Out:
# array([[-821.73337832]])

# %% [markdown]
# <h4>What is the final estimated linear model we get?</h3>

# %% [markdown]
# As we saw above, we should get a final linear model with the structure:

# %% [markdown]
# $$
# Yhat = a + b  X
# $$

# %% [markdown]
# Plugging in the actual values we get:

# %% [markdown]
# $$
# price = 38423.31 - 821.73 x  highway-mpg
# $$

# %% [markdown]
# <H3>b. Train the model using 'engine-size' as the independent variable and 'price' as the dependent variable?

# %%
# Set model object
lm2 = LinearRegression()

# %%
# Determine X2 =  'engine-size' 
X2 = df[['engine-size' ]]

# %%
# Fit the model
lm2.fit(X2,Y)
# Out:
# LinearRegression()

# %%
# Predict 
Y2hat = lm2.predict(X2)
Y2hat[:5]
# Out:
# array([[13728.4631336 ],
#        [13728.4631336 ],
#        [17399.38347881],
#        [10224.40280408],
#        [14729.62322775]])

# %%
# Slope (b2)
b2 = lm2.coef_
b2
# Out:
# array([[166.86001569]])

# %%
# Intercept (a2)
a2 = lm2.intercept_
a2
# Out:
# array([-7963.33890628])

# %% [markdown]
# ##### What is the equation of the predicted line. You can use x and yhat or 'engine-size' or 'price'?
# $$
# Yhat2 = -7963.33 + 166.86*X2
# $$

# %% [markdown]
# Double-click <b>here</b> for the solution.
#
# <!-- The answer is below:
#
# lm1.fit(df[['engine-size']], df[['price']])
# lm1
#
# -->

# %% [markdown]
# Double-click <b>here</b> for the solution.
#
# <!-- The answer is below:
#
# # Slope
# lm1.coef_
# # Intercept
# lm1.intercept_
#
# -->

# %% [markdown]
# Double-click <b>here</b> for the solution.
#
# <!-- The answer is below:
#
# # using X and Y
# Yhat=38423.31-821.733*X
#
# Price=38423.31-821.733*engine-size
#
# -->

# %% [markdown]
# <h2>2. Multiple Linear Regression</h4>

# %% [markdown]
# <p>What if we want to predict car price using more than one variable?</p>
#
# <p>If we want to use more variables in our model to predict car price, we can use <b>Multiple Linear Regression</b>.
# Multiple Linear Regression is very similar to Simple Linear Regression, but this method is used to explain the relationship between one continuous response (dependent) variable and <b>two or more</b> predictor (independent) variables.
# Most of the real-world regression models involve multiple predictors. We will illustrate the structure by using four predictor variables, but these results can generalize to any integer:</p>

# %% [markdown]
# $$
# Y: Response \ Variable\\
# X_1 :Predictor\ Variable \ 1\\
# X_2: Predictor\ Variable \ 2\\
# X_3: Predictor\ Variable \ 3\\
# X_4: Predictor\ Variable \ 4\\
# $$

# %% [markdown]
# $$
# a: intercept\\
# b_1 :coefficients \ of\ Variable \ 1\\
# b_2: coefficients \ of\ Variable \ 2\\
# b_3: coefficients \ of\ Variable \ 3\\
# b_4: coefficients \ of\ Variable \ 4\\
# $$

# %% [markdown]
# The equation is given by

# %% [markdown]
# $$
# Yhat = a + b_1 X_1 + b_2 X_2 + b_3 X_3 + b_4 X_4
# $$

# %% [markdown]
# <p>From the previous section  we know that other good predictors of price could be:</p>
# <ul>
#     <li>Horsepower</li>
#     <li>Curb-weight</li>
#     <li>Engine-size</li>
#     <li>Highway-mpg</li>
# </ul>
# Let's develop a model using these variables as the predictor variables.

# %% [markdown]
# <h4>Let's develop a model using these variables as the predictor variables.

# %%
# Setup model object
MLR1 = LinearRegression()

# %%
# Determine X[horsepower, curb-weight, engine-size, highway-mpg]
X = df[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']]
Y = df[['price']]

# %% [markdown]
# <h4>Fit the linear model using the four above-mentioned variables.

# %%
# Code
MLR1.fit(X,Y)
# Out:
# LinearRegression()

# %% [markdown]
# <h4>What is the value of the intercept(A)?

# %%
# Code:
A = MLR1.intercept_
A
# Out:
# array([-15811.86376773])

# %% [markdown]
# <h4>What are the values of the coefficients (b1, b2, b3, b4)?

# %%
# Code
B = MLR1.coef_
B
# Out:
# array([[53.53022809,  4.70805253, 81.51280006, 36.1593925 ]])

# %% [markdown]
# <h4> What is the final estimated linear model that we get?

# %% [markdown]
# As we saw above, we should get a final linear function with the structure:
#
# $$
# Yhat = a + b_1 X_1 + b_2 X_2 + b_3 X_3 + b_4 X_4
# $$
#
# What is the linear function we get in this example?

# %% [markdown]
# $$
# Price = -15678.742628061467 + 52.65851272 x horsepower + 4.69878948 x curb-weight + 81.95906216 x engine-size + 33.58258185 x highway-mpg
# $$

# %% [markdown]
# ### Create and train a Multiple Linear Regression
#
# Model "MLR" where the response variable is price, and the predictor variable is 'normalized-losses' and  'highway-mpg'.

# %%
# Create model
MLR2 = LinearRegression()
# Determin X,Y
Xm = df[['normalized-losses','highway-mpg']]
Y = df[['price']]
# Train/fit the model
MLR2.fit(Xm,Y)
# Predict
Ymhat = MLR2.predict(Xm)
Ymhat[:5]
# Out:
# array([[16231.78938339],
#        [16231.78938339],
#        [17052.24372355],
#        [13833.33798916],
#        [20396.97271047]])

# %% [markdown]
# Double-click <b>here</b> for the solution.
#
# <!-- The answer is below:
#
# lm2 = LinearRegression()
# lm2.fit(df[['normalized-losses' , 'highway-mpg']],df['price'])
#
# -->

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <h1>Question  #2 b): </h1>
# <b>Find the coefficient of the model?</b>
# </div>

# %%
# Intercept (Am)
Am = MLR2.intercept_
Am
# Out:
# array([38201.31327246])

# %%
# Slope
Bm = MLR2.coef_
Bm
# Out:
# array([[   1.49789586, -820.45434016]])

# %% [markdown]
# <h4> Equotation: </h4>
# $$
# Ymhat = 38201.3 + 1.49X1. -  -820.45X2
# $$

# %% [markdown]
# Double-click <b>here</b> for the solution.
#
# <!-- The answer is below:
#
# lm2.coef_
#
# -->

# %% [markdown]
# <h2>3. Model Evaluation using Visualization

# %% [markdown]
# Now that we've developed some models, how do we evaluate our models and how do we choose the best one? One way to do this is by using visualization.

# %% [markdown]
# <h4> Import the visualization package: seaborn

# %%
# Code:
import seaborn as sns

# %% [markdown]
# <h3>A. Regression Plot</h3>

# %% [markdown]
# <p>When it comes to simple linear regression, an excellent way to visualize the fit of our model is by using <b>regression plots</b>.</p>
#
# <p>This plot will show a combination of a scattered data points (a <b>scatter plot</b>), as well as the fitted <b>linear regression</b> line going through the data. This will give us a reasonable estimate of the relationship between the two variables, the strength of the correlation, as well as the direction (positive or negative correlation).</p>

# %% [markdown]
#  <b>Let's visualize Horsepower as potential predictor variable of price:

# %%
# Code:
plt.figure(figsize=(14,6))
sns.scatterplot(data=df, x='horsepower', y='price')

plt.title('Relationship between horsepower and price', fontdict={'color':'b', 'weight':'bold', 'fontstyle':'italic', 'fontsize':20})

plt.show()
plt.close()

# %% [markdown]
# <b>Let's visualize highway-mpg as potential predictor variable of price:

# %%
# Code:
plt.figure(figsize=(14,6))
sns.scatterplot(data=df, x='highway-mpg', y='price')

plt.title('Relationship between highway-mpg and price', fontdict={'color':'b', 'weight':'bold', 'fontstyle':'italic', 'fontsize':20})

plt.show()
plt.close()

# %% [markdown]
# <p>We can see from this plot that price is negatively correlated to highway-mpg, since the regression slope is negative.
# One thing to keep in mind when looking at a regression plot is to pay attention to how scattered the data points are around the regression line. This will give you a good indication of the variance of the data, and whether a linear model would be the best fit or not. If the data is too far off from the line, this linear model might not be the best model for this data.

# %% [markdown]
# <b> Let's compare this plot to the regression plot of "peak-rpm".</p>

# %%
# Code:
plt.figure(figsize=(14,6))
sns.scatterplot(data=df, x='peak-rpm', y='price')

plt.title('Relationship between peak-rpm and price', fontdict={'color':'b', 'weight':'bold', 'fontstyle':'italic', 'fontsize':20})

plt.show()
plt.close()

# %% [markdown]
# <p>Comparing the regression plot of "peak-rpm" and "highway-mpg" we see that the points for "highway-mpg" are much closer to the generated line and on the average decrease. The points for "peak-rpm" have more spread around the predicted line, and it is much harder to determine if the points are decreasing or increasing as the "highway-mpg" increases.</p>

# %% [markdown]
# <b>Given the regression plots above is "peak-rpm" or "highway-mpg" more strongly correlated with "price". Use the method  ".corr()" to verify your answer.</b>

# %%
# Code:
df[['price','highway-mpg','peak-rpm']].corr()
# Out:
#                 price  highway-mpg  peak-rpm
# price        1.000000    -0.704692 -0.101612
# highway-mpg -0.704692     1.000000 -0.058598
# peak-rpm    -0.101612    -0.058598  1.000000

# %% [markdown]
# Double-click <b>here</b> for the solution.
#
# <!-- The answer is below:
#
# The variable "peak-rpm" has a stronger correlation with "price", it is approximate -0.704692  compared to   "highway-mpg" which is approximate     -0.101616. You can verify it using the following command:
# df[["peak-rpm","highway-mpg","price"]].corr()
#
# -->

# %% [markdown]
# <h3> B. Residual Plot</h3>
#
# <p>A good way to visualize the variance of the data is to use a residual plot.</p>
#
# <p>What is a <b>residual</b>?</p>
#
# <p>The difference between the observed value (y) and the predicted value (Yhat) is called the residual (e). When we look at a regression plot, the residual is the distance from the data point to the fitted regression line.</p>
#
# <p>So what is a <b>residual plot</b>?</p>
#
# <p>A residual plot is a graph that shows the residuals on the vertical y-axis and the independent variable on the horizontal x-axis.</p>
#
# <p>What do we pay attention to when looking at a residual plot?</p>
#
# <p>We look at the spread of the residuals:</p>
#
# <p>- If the points in a residual plot are <b>randomly spread out around the x-axis</b>, then a <b>linear model is appropriate</b> for the data. Why is that? Randomly spread out residuals means that the variance is constant, and thus the linear model is a good fit for this data.</p>

# %%
# Residual plot for highway-mpg vs price
plt.figure(figsize=(14,6))
sns.residplot(data=df, x='highway-mpg', y='price')

plt.title('Residual plot for highway-mpg vs price', fontdict={'color':'b', 'weight':'bold', 'fontstyle':'italic', 'fontsize':20})

plt.show()
plt.close()

# %% [markdown]
# <i>What is this plot telling us?</i>
#
# <p>We can see from this residual plot that the residuals are not randomly spread around the x-axis, which leads us to believe that maybe a non-linear model is more appropriate for this data.</p>

# %% [markdown]
# <h3>C. Multiple Linear Regression</h3>

# %% [markdown]
# <p>How do we visualize a model for Multiple Linear Regression? This gets a bit more complicated because you can't visualize it with regression or residual plot.</p>
#
# <p>One way to look at the fit of the model is by looking at the <b>distribution plot</b>: We can look at the distribution of the fitted values that result from the model and compare it to the distribution of the actual values.</p>

# %%
# Using LRM1 for ['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']

# %% [markdown]
# First lets make a prediction

# %%
# Prediction Yhatm
Yhatm1 = MLR1.predict(X)
Yhatm1[:5]
# Out:
# array([[13699.07700462],
#        [13699.07700462],
#        [19052.71346719],
#        [10620.61524404],
#        [15520.90025344]])

# %% [markdown]
# <b> The distribution plot

# %%
# Remove warnings
# import warnings
# warnings.filterwarnings('ignore')

# %%
# Distribution plot
plt.figure(figsize=(14,6))

sns.kdeplot(df['price'], label='Actual Values', color='green')
sns.kdeplot(Yhatm1, label='Predicted Values', color='red', palette='Set1')

plt.legend() # Show label
plt.title('Actual vs Predicted price using Multiple Linear Regression', fontdict={'color':'b', 'weight':'bold', 'fontstyle':'italic', 'fontsize':20})

plt.show()
plt.close()
plt.show()
plt.close()

# %% [markdown]
# <p>We can see that the fitted values are reasonably close to the actual values, since the two distributions overlap a bit. However, there is definitely some room for improvement.</p>

# %% [markdown]
# <h3>D. Polynomial Regression

# %% [markdown]
# <p><b>Polynomial regression</b> is a particular case of the general linear regression model or multiple linear regression models.</p>
# <p>We get non-linear relationships by squaring or setting higher-order terms of the predictor variables.</p>
#
# <p>There are different orders of polynomial regression:</p>

# %% [markdown]
# <center><b>Quadratic - 2nd order</b></center>
# $$
# Yhat = a + b_1 X^2 +b_2 X^2
# $$
#
#
# <center><b>Cubic - 3rd order</b></center>
# $$
# Yhat = a + b_1 X^2 +b_2 X^2 +b_3 X^3\\
# $$
#
#
# <center><b>Higher order</b>:</center>
# $$
# Y = a + b_1 X^2 +b_2 X^2 +b_3 X^3 ....\\
# $$

# %% [markdown]
# <p>We saw earlier that a linear model did not provide the best fit while using highway-mpg as the predictor variable. Let's see if we can try fitting a polynomial model to the data instead.</p>

# %% [markdown]
# <b>Lets get the variables: Use highway-mpg (X1) vs price (Y)

# %%
# np.polyfit expected 1D vector for x not dataframe
X1 = df['highway-mpg']
Y1 = df['price']

# %% [markdown]
# <b> Let's fit the polynomial using the function <b>polyfit</b> of the 3rd order, then use the function <b>poly1d</b> to display the polynomial function.

# %%
# np.polyfit(x,y,3): Hàm này thực hiện fitting đa thức (tìm đa thức tốt nhất để khớp với dữ liệu).
f3 = np.polyfit(X1,Y1,3)

# %%
# np.poly1d (f): Hàm này tạo một đối tượng đa thức từ các hệ số đã tính được ở bước trên.
poly3 = np.poly1d(f3)

# %% [markdown]
# <b> Create a test X randomly

# %%
# np.linspace(15, 55, 100) hữu ích khi bạn muốn tạo một mảng số có giá trị trong khoảng xác định, 
# với số lượng và khoảng cách các giá trị được kiểm soát.
X_test = np.linspace(15,55,100)

# %%
# Using model pm to calculate Y_test
Y_test = poly3(X_test)
Y_test[:5]
# Out:
# array([44258.16161873, 42714.9848919 , 41215.17312753, 39758.11027931,
#        38343.18030097])

# %% [markdown]
# <b> We will use the following code to plot the data:

# %%
# Code
plt.figure(figsize=(14,8))
plt.plot(X1,Y1,'.',X_test, Y_test,'-')

plt.title('Polynomial Regression Line on Cubic - 3rd order', fontdict={'color':'b', 'weight':'bold', 'fontstyle':'italic', 'fontsize':20})
plt.show()
plt.close()

# %% [markdown]
# <p>We can already see from plotting that this polynomial model performs better than the linear model. This is because the generated polynomial function  "hits" more of the data points.</p>

# %% [markdown]
# <b>Create 11 order polynomial model with the variables x and y from above?</b>

# %%
# Create 11 order polynomial model with the variables x and y from above
f11 = np.polyfit(X1,Y1,11)
poly11 = np.poly1d(f11)

# %%
# Create x_test11, y_test11
x_test11 = np.linspace(15,55,100)
y_test11 = poly11(x_test11)

# %%
# Visualize
plt.figure(figsize=(14,8))
plt.plot(X1,Y1,'.', x_test11, y_test11,'-')

plt.title('Polynomial Regression Line on 11st order', fontdict={'color':'b', 'weight':'bold', 'fontstyle':'italic', 'fontsize':20})

plt.show()
plt.close()

# %% [markdown]
# Double-click <b>here</b> for the solution.
#
# <!-- The answer is below:
#
# # calculate polynomial
# # Here we use a polynomial of the 3rd order (cubic)
# f1 = np.polyfit(x, y, 11)
# p1 = np.poly1d(f1)
# print(p)
# PlotPolly(p1,x,y, 'Length')
#
# -->

# %% [markdown]
# <h3>Multivariate Polynomial

# %% [markdown]
# <p>The analytical expression for Multivariate Polynomial function gets complicated. For example, the expression for a second-order (degree=2)polynomial with two variables is given by:</p>

# %% [markdown]
# $$
# Yhat = a + b_1 X_1 +b_2 X_2 +b_3 X_1 X_2+b_4 X_1^2+b_5 X_2^2
# $$

# %% [markdown]
# We can perform a polynomial transform on multiple features. First, we import the module:

# %%
# Import PolynomialFeatures module from :
from sklearn.preprocessing import PolynomialFeatures

# %% [markdown]
# We create a <b>PolynomialFeatures</b> object of degree 2:

# %%
# Code:
MulPoly = PolynomialFeatures(degree=2)

# %%
# fit_transform tính các thành phần chính của dữ liệu và chuyển dữ liệu sang không gian mới, 
# giữ lại 1 chiều (do n_components=1).
X_pr = MulPoly.fit_transform(X)

# %% [markdown]
# The original data is of 201 samples and 4 features

# %%
# Code:
X.shape
# Out:
# (201, 4)

# %% [markdown]
# after the transformation, there 201 samples and 15 features

# %%
# Code:
X_pr.shape
# Out:
# (201, 15)

# %% [markdown]
# <h2>4. Pipeline</h2>

# %% [markdown]
# <p>Data Pipelines simplify the steps of processing the data. We use the module <b>Pipeline</b> to create a pipeline. We also use <b>StandardScaler</b> as a step in our pipeline.</p>

# %%
# Import module Pipeline (from sklearn.pipeline) and StandardScaler (sklearn.preprocessing)
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# <b> We create the pipeline, by creating a list of tuples including the name of the model or estimator and its corresponding constructor.

# %%
# Create a Pipeline 'Input'
Input = [('scale',StandardScaler()), ('polynomial', PolynomialFeatures(include_bias=False)),('model',LinearRegression())]

# %% [markdown]
# Double-click <b>here</b> for the Explaination:
# <!--
# Code này định nghĩa một danh sách Input, bao gồm các tuple với cấu trúc (tên bước, đối tượng hoặc lớp liên quan), thường được dùng trong pipeline của thư viện scikit-learn để xây dựng quy trình tiền xử lý và huấn luyện mô hình. Hãy phân tích từng phần:
#
# 1. Cấu trúc và Mục đích
# python
# Copy code
# Input = [('scale', StandardScaler),
#          ('polynomial', PolynomialFeatures(include_bias=False)),
#          ('model', LinearRegression)]
# Đây là một danh sách các bước xử lý, được viết dưới dạng các tuple:
#
# Phần đầu tiên trong mỗi tuple là tên bước (dạng chuỗi), giúp xác định rõ nhiệm vụ của bước đó.
# Phần thứ hai là đối tượng hoặc lớp của công cụ/mô hình thực hiện nhiệm vụ.
# Danh sách này thường được truyền vào hàm Pipeline của scikit-learn để tự động hóa quy trình xử lý dữ liệu và huấn luyện mô hình.
#
# 2. Giải thích từng bước
# a. 'scale', StandardScaler
# StandardScaler:
# Chuẩn hóa dữ liệu bằng cách loại bỏ trung bình và chia giá trị cho độ lệch chuẩn (standard deviation).
# Công cụ này giúp đưa các đặc trưng (features) về cùng một tỷ lệ, tránh việc một đặc trưng chi phối quá mức.
# b. 'polynomial', PolynomialFeatures(include_bias=False)
# PolynomialFeatures:
# Tạo thêm các đặc trưng bậc cao (polynomial features) từ dữ liệu ban đầu.
# Tham số include_bias=False đảm bảo không tạo thêm cột hệ số bias (hằng số).
#
# c. 'model', LinearRegression
# LinearRegression:
# Mô hình hồi quy tuyến tính.
# Sử dụng để học và dự đoán từ các đặc trưng đã được chuẩn hóa và biến đổi.
# 3. Mục đích tổng thể
# Danh sách này mô tả quy trình sau:
#
# Dữ liệu được chuẩn hóa.
# Các đặc trưng bậc cao được tạo ra từ dữ liệu đã chuẩn hóa.
# Mô hình hồi quy tuyến tính được huấn luyện trên dữ liệu mới.
# 4. Sử dụng với Pipeline
# Danh sách này thường được truyền vào một pipeline như sau:
#
# python
# Copy code
# from sklearn.pipeline import Pipeline
#
# pipeline = Pipeline(Input)
# Pipeline trên cho phép bạn thực hiện tuần tự các bước từ chuẩn hóa dữ liệu, tạo đặc trưng, đến huấn luyện mô hình một cách tự động.
#
# 5. Ưu điểm
# Tự động hóa: Thay vì xử lý từng bước riêng lẻ, pipeline cho phép ghép nối các bước thành một quy trình duy nhất.
# Tái sử dụng: Sau khi định nghĩa, pipeline có thể được áp dụng cho cả dữ liệu huấn luyện và kiểm tra.
# Bảo trì dễ dàng: Việc thay đổi hoặc thêm bước chỉ cần cập nhật danh sách Input.
# --->

# %% [markdown]
# <b>We input the list as an argument to the pipeline constructor

# %%
# Pipline constructor
pipe = Pipeline(Input)
pipe
# Out:
# Pipeline(steps=[('scale', StandardScaler()),
#                 ('polynomial', PolynomialFeatures(include_bias=False)),
#                 ('model', LinearRegression())])

# %% [markdown]
# <b> We can normalize the data,  perform a transform and fit the model simultaneously.

# %%
# Fit the pipeline model:
pipe.fit(X,Y)
# Out:
# Pipeline(steps=[('scale', StandardScaler()),
#                 ('polynomial', PolynomialFeatures(include_bias=False)),
#                 ('model', LinearRegression())])

# %% [markdown]
# <b> Similarly,  we can normalize the data, perform a transform and produce a prediction  simultaneously

# %%
# Predict
yhat_pipe = pipe.predict(X)
yhat_pipe[:5]
# Out:
# array([[13102.93329646],
#        [13102.93329646],
#        [18226.43450275],
#        [10391.09183955],
#        [16135.53737535]])

# %% [markdown]
# <b>Create a pipeline that Standardizes the data, then perform prediction using a linear regression model using the features X and targets Y</b>

# %%
# Create new pipeline
pipe1 = Pipeline([('scale',StandardScaler()),('model', LinearRegression())])

# %%
# Name the pipe

# %%
# Fit the pipe
pipe1.fit(X,Y)
# Out:
# Pipeline(steps=[('scale', StandardScaler()), ('model', LinearRegression())])

# %%
# Make prediction
yhat_pipe1 = pipe.predict(X)
yhat_pipe1[:5]
# Out:
# array([[13102.93329646],
#        [13102.93329646],
#        [18226.43450275],
#        [10391.09183955],
#        [16135.53737535]])

# %%
# Distribution plot
plt.figure(figsize=(14,6))

sns.kdeplot(yhat_pipe, label='yhat_pipe with Polinomial', color='green')
sns.kdeplot(yhat_pipe1, label='yhat_pipe1', color='red', palette='Set1')

plt.legend() # Show label
plt.title('Actual vs Predicted price using Multiple Linear Regression', fontdict={'color':'b', 'weight':'bold', 'fontstyle':'italic', 'fontsize':20})

plt.show()
plt.close()
plt.show()
plt.close()

# %% [markdown]
# </div>
# Double-click <b>here</b> for the solution.
#
# <!-- The answer is below:
#
# Input=[('scale',StandardScaler()),('model',LinearRegression())]
#
# pipe=Pipeline(Input)
#
# pipe.fit(Z,y)
#
# ypipe=pipe.predict(Z)
# ypipe[0:10]
#
# -->

# %% [markdown]
# <h1 align=center><font size=6>Module 5: Model Evaluation and Refinement</font></h1>

# %% [markdown]
# We have built models and made predictions of vehicle prices. Now we will determine how accurate these predictions are.

# %% [markdown]
# <h1>Model Evaluation</h1>

# %% [markdown]
# <h2>1. Measures for In-Sample Evaluation</h2>

# %% [markdown]
# <p>When evaluating our models, not only do we want to visualize the results, but we also want a quantitative measure to determine how accurate the model is.</p>
#
# <p>Two very important measures that are often used in Statistics to determine the accuracy of a model are:</p>
# <ul>
#     <li><b>R^2 / R-squared</b></li>
#     <li><b>Mean Squared Error (MSE)</b></li>
# </ul>
#
# <b>R-squared</b>
#
# <p>R squared, also known as the coefficient of determination, is a measure to indicate how close the data is to the fitted regression line.</p>
#
# <p>The value of the R-squared is the percentage of variation of the response variable (y) that is explained by a linear model.</p>
#
#
#
# <b>Mean Squared Error (MSE)</b>
#
# <p>The Mean Squared Error measures the average of the squares of errors, that is, the difference between actual value (y) and the estimated value (ŷ).</p>

# %% [markdown]
# <h3>Model 1: Simple Linear Regression</h3>

# %% [markdown]
# <b> Let's calculate the R^2

# %%
# highway_mpg_fit
X1 = df[['highway-mpg']]
lm.fit(X1,Y)
# Out:
# LinearRegression()

# %%
# Find the R^2
print('R^2 is: ',lm.score(X1,Y))
# Out:
# R^2 is:  0.4965911884339176

# %% [markdown]
# We can say that ~ 49.659% of the variation of the price is explained by this simple linear model "highway_mpg_fit".

# %% [markdown]
# <b> Let's calculate the MSE

# %%
# We can predict the output i.e., "yhat" using the predict method, 
# where X is the input variable:
Yhat1 = lm.predict(X1)

# %%
# Lets import the function mean_squared_error from the module metrics
from sklearn.metrics import mean_squared_error

# %% [markdown]
# <b>We compare the predicted results with the actual results

# %%
# Code
mse = mean_squared_error(Y,Yhat1)
mse
# Out:
# 31635042.944639888

# %% [markdown]
# <h3>Model 2: Multiple Linear Regression</h3>

# %% [markdown]
# <b>Let's calculate the R^2

# %%
# Fit the model 
X.head(2)
lm.fit(X,Y)
# Out:
# LinearRegression()

# %%
# # Find the R^2
print('R^2: ', lm.score(X,Y))
# Out:
# R^2:  0.8093732522175299

# %% [markdown]
# We can say that ~ 80.937 % of the variation of price is explained by this multiple linear regression "multi_fit".

# %% [markdown]
# <b>Let's calculate the MSE

# %%
# We produce a prediction
Yhat = lm.predict(X)

# %%
# We compare the predicted results with the actual results
MSE = mean_squared_error(Y,Yhat)
MSE
# Out:
# 11979300.349818882

# %% [markdown]
# <h3>Model 3: Polynomial Fit</h3>

# %%
# Determin yhat_poly
yhat_poly3 = poly3(X1)

# %% [markdown]
# <b> Let's calculate the R^2

# %%
# Let’s import the function r2_score from the module metrics as we are using a different function
from sklearn.metrics import r2_score

# %%
# We apply the function to get the value of r^2
R_square = r2_score(Y,yhat_poly3) 
R_square
# Out:
# 0.674194666390652

# %% [markdown]
# We can say that ~ 67.419 % of the variation of price is explained by this polynomial fit

# %% [markdown]
# <h3>MSE</h3>

# %%
# We can also calculate the MSE:  
MSE_poly3 = mean_squared_error(Y,yhat_poly3)
MSE_poly3
# Out:
# 20474146.426361207

# %% [markdown]
# <B>  Mean square error is 20,474,146

# %% [markdown]
# <h3>=> Prediction and Decision Making</h3>
# <h3>Prediction</h3>
#
# <p>In the previous section, we trained the model using the method <b>fit</b>. Now we will use the method <b>predict</b> to produce a prediction. Lets import <b>pyplot</b> for plotting; we will also be using some functions from numpy.</p>

# %%
# Import LinearRegression
from sklearn.linear_model import LinearRegression
# Create LinearRegression object
lm = LinearRegression()

# %%
# Import visualiztion libraries
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
 
import numpy as np

# Create a new input
x_input = np.arange(1,100,1).reshape(-1,1)

# %%
 # Fit the model 
lm.fit(X1,Y)
# Out:
# LinearRegression()

# %%
# Produce a prediction
yhat = lm.predict(x_input)
# Out:
# C:\Users\TrinhQuynh\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
# Plot the data 

plt.plot(x_input,yhat)

# %% [markdown]
# <h3>Decision Making: Determining a Good Model Fit</h3>

# %% [markdown]
# <p>Now that we have visualized the different models, and generated the R-squared and MSE values for the fits, how do we determine a good model fit?
# <ul>
#     <li><i>What is a good R-squared value?</i></li>
# </ul>
# </p>
#
# <p>When comparing models, <b>the model with the higher R-squared value is a better fit</b> for the data.
# <ul>
#     <li><i>What is a good MSE?</i></li>
# </ul>
# </p>
#
# <p>When comparing models, <b>the model with the smallest MSE value is a better fit</b> for the data.</p>
#
#
# <h4>Let's take a look at the values for the different models.</h4>
# <p>Simple Linear Regression: Using Highway-mpg as a Predictor Variable of Price.
# <ul>
#     <li>R-squared: 0.49659118843391759</li>
#     <li>MSE: 3.16 x10^7</li>
# </ul>
# </p>
#
# <p>Multiple Linear Regression: Using Horsepower, Curb-weight, Engine-size, and Highway-mpg as Predictor Variables of Price.
# <ul>
#     <li>R-squared: 0.80896354913783497</li>
#     <li>MSE: 1.2 x10^7</li>
# </ul>
# </p>
#
# <p>Polynomial Fit: Using Highway-mpg as a Predictor Variable of Price.
# <ul>
#     <li>R-squared: 0.6741946663906514</li>
#     <li>MSE: 2.05 x 10^7</li>
# </ul>
# </p>

# %% [markdown]
# <h3>Simple Linear Regression model (SLR) vs Multiple Linear Regression model (MLR)</h3>

# %% [markdown]
# <p>Usually, the more variables you have, the better your model is at predicting, but this is not always true. Sometimes you may not have enough data, you may run into numerical problems, or many of the variables may not be useful and or even act as noise. As a result, you should always check the MSE and R^2.</p>
#
# <p>So to be able to compare the results of the MLR vs SLR models, we look at a combination of both the R-squared and MSE to make the best conclusion about the fit of the model.
# <ul>
#     <li><b>MSE</b>The MSE of SLR is  3.16x10^7  while MLR has an MSE of 1.2 x10^7.  The MSE of MLR is much smaller.</li>
#     <li><b>R-squared</b>: In this case, we can also see that there is a big difference between the R-squared of the SLR and the R-squared of the MLR. The R-squared for the SLR (~0.497) is very small compared to the R-squared for the MLR (~0.809).</li>
# </ul>
# </p>
#
# This R-squared in combination with the MSE show that MLR seems like the better model fit in this case, compared to SLR.

# %% [markdown]
# <h3>Simple Linear Model (SLR) vs Polynomial Fit</h3>

# %% [markdown]
# <ul>
#     <li><b>MSE</b>: We can see that Polynomial Fit brought down the MSE, since this MSE is smaller than the one from the SLR.</li>
#     <li><b>R-squared</b>: The R-squared for the Polyfit is larger than the R-squared for the SLR, so the Polynomial Fit also brought up the R-squared quite a bit.</li>
# </ul>
# <p>Since the Polynomial Fit resulted in a lower MSE and a higher R-squared, we can conclude that this was a better fit model than the simple linear regression for predicting Price with Highway-mpg as a predictor variable.</p>

# %% [markdown]
# <h3>Multiple Linear Regression (MLR) vs Polynomial Fit</h3>

# %% [markdown]
# <ul>
#     <li><b>MSE</b>: The MSE for the MLR is smaller than the MSE for the Polynomial Fit.</li>
#     <li><b>R-squared</b>: The R-squared for the MLR is also much larger than for the Polynomial Fit.</li>
# </ul>

# %% [markdown]
# <h3>Conclusion:</h2>

# %% [markdown]
# <p>Comparing these three models, we conclude that <b>the MLR model is the best model</b> to be able to predict price from our dataset. This result makes sense, since we have 27 variables in total, and we know that more than one of those variables are potential predictors of the final car price.</p>

# %%
# from IPython.html import widgets -> Dòng này đã lỗi thời. Thay vào đó, nên sử dụng ipywidgets (được nhập ở dòng 4).
# from IPython.display import display -> Dòng này giống hệt dòng đầu tiên. Nếu đã có dòng đầu tiên, dòng này là dư thừa và có thể bỏ đi.

# %% [markdown]
# <h2 id="ref1">2. Training and Testing Evaluation Model (Measures for Out of sample data Evaluation)</h2>
#
# An important step in testing your model is to split your data into training and testing data. We will place the target data <b>price</b> in a separate dataframe <b>y</b>

# %% [markdown]
# <h4>Functions for plotting</h2>

# %% [markdown]
# - xtrain, ytrain: training data
# - xtest, ytest: testing data
# - lr:  linear regression object
# - poly_transform:  polynomial transformation object

# %%
# Determine features (x) data
x = df.select_dtypes(include='number').drop('price', axis='columns')
y = df['price']
x.shape
# Out:
# (201, 21)

# %% [markdown]
# a. Now we randomly split our data into training and testing data  using the function <b>train_test_split</b>.

# %%
# Let's import LinearRegression from the module linear_model.
from sklearn.model_selection import train_test_split

# Split:
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state=0)

print("number of test samples :", xtest.shape[0])
print("number of training samples:",xtrain.shape[0])
# Out:
# number of test samples : 41
# number of training samples: 160

# %% [markdown]
# The <b>test_size</b> parameter sets the proportion of data that is split into the testing set. In the above, the testing set is set to 10% of the total dataset.

# %%
# We create a Linear Regression object:
lr = LinearRegression()
lr
# Out:
# LinearRegression()

# %%
# Fit the model using the feature horsepower
lr.fit(xtrain, ytrain)
# Out:
# LinearRegression()

# %%
# Let's Calculate the R^2 on the test data:
r_squared = lr.score(xtest,ytest)
r_squared
# Out:
# 0.7923693974837892

# %% [markdown]
# <b>Use the function "train_test_split" to split up the data set such that 40% of the data samples will be utilized for testing, set the parameter "random_state" equal to zero. The output of the function should be the following:  xtrain1, xtest1, ytrain1, ytest.</b>

# %%
# Determine feature and target
x1 = df[['horsepower']]
y = df['price']

# %%
# Write your code below and press Shift+Enter to execute 
xtrain1, xtest1, ytrain1, ytest1 = train_test_split(x1, y, test_size=0.4, random_state=0)

# %%
# Let's import LinearRegression from the module linear_model
from sklearn.linear_model import LinearRegression

# %%
# Create a Linear Regression object:
lr1 = LinearRegression()

# %%
# Fit the model using the feature horsepower 
lr1.fit(xtrain1[['horsepower']], ytrain1)
# Out:
# LinearRegression()

# %%
# Let's Calculate the R^2 on the test data:
r_squared1 = lr1.score(xtest1[['horsepower']], ytest1)
r_squared1
# Out:
# 0.7139737368233016

# %% [markdown]
# we can see the R^2 is much smaller using the test data.

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# Sometimes you do not have sufficient testing data; as a result, you may want to perform Cross-validation. Let's  go over several methods that you can use for  Cross-validation.

# %% [markdown]
# <h2>Cross-validation Score</h2>

# %%
# Lets import the module cross_val_score from model_selection.
from sklearn.model_selection import cross_val_score

# %%
# We input the object, the feature in this case ' horsepower', the target data (Y). 
# The parameter 'cv'  determines the number of folds; in this case 4. 

Rcross = cross_val_score(lr1, x1, y, cv=4)

# %%
# The default scoring is R^2; each element in the array has the average  R^2 value in the fold:
Rcross
# Out:
# array([0.77465419, 0.51718424, 0.74814454, 0.04825398])

# %%
# We can calculate the average and standard deviation of our estimate:
print("The mean of the folds are", Rcross.mean(), "and the standard deviation is" , Rcross.std())
# Out:
# The mean of the folds are 0.5220592359225414 and the standard deviation is 0.29130480666118436

# %%
# We can use negative squared error as a score by setting the parameter  'scoring' metric to 'neg_mean_squared_error'. 
-1 * cross_val_score(lr1,x1, y,cv=4,scoring='neg_mean_squared_error')
# Out:
# array([20251357.7835463 , 43743920.05390439, 12525158.34507633,
#        17564549.69976653])

# %% [markdown]
# <b>
# Calculate the average R^2 using two folds, find the average R^2 for the second fold utilizing the horsepower as a feature :
# </b>

# %%
# Write your code below and press Shift+Enter to execute 
Rcross1 = cross_val_score(lr1,x1,y,cv=2)
print('Rcross are: ', Rcross1)
print("The mean of the folds are", Rcross1.mean(), "and the standard deviation is" , Rcross1.std())
# Out:
# Rcross are:  [0.59020493 0.44346527]
# The mean of the folds are 0.516835099979672 and the standard deviation is 0.07336982731492742

# %% [markdown]
# You can also use the function 'cross_val_predict' to predict the output. The function splits up the data into the specified number of folds, using one fold to get a prediction while the rest of the folds are used as test data. First import the function:

# %%
# Code:

from sklearn.model_selection import cross_val_predict

# %% [markdown]
# We input the object, the feature in this case <b>'horsepower'</b> , the target data <b>Y</b>. The parameter 'cv' determines the number of folds; in this case 4. We can produce an output:

# %%
# Code:

yhat = cross_val_predict(lr1, x1, y,cv=4)
yhat[0:5]
# Out:
# array([14142.23793549, 14142.23793549, 20815.3029844 , 12745.549902  ,
#        14762.9881726 ])

# %%
# mse:
mse = mean_squared_error(y, yhat)
mse
# Out:
# 23504978.367652856

# %% [markdown]
# <h1 id="ref2">Part 2: Overfitting, Underfitting and Model Selection</h1>
#
# <p>It turns out that the test data sometimes referred to as the out of sample data is a much better measure of how well your model performs in the real world.  One reason for this is overfitting; let's go over some examples. It turns out these differences are more apparent in Multiple Linear Regression and Polynomial Regression so we will explore overfitting in that context.</p>

# %% [markdown]
# Let's create Multiple linear regression objects and train the model using <b>'horsepower'</b>, <b>'curb-weight'</b>, <b>'engine-size'</b> and <b>'highway-mpg'</b> as features.

# %%
# Determine features and target:
X = df[['horsepower', 'curb-weight', 'engine-size','highway-mpg']] 
Y = df['price']
# Split data
Xtrain, Xtest, Ytrain, Ytest = train_test_split(X, Y, test_size=0.1, random_state=0)

# Import Linear Regression and create linear object:
from sklearn.linear_model import LinearRegression

Lr = LinearRegression()

# Fit (train) the data
Lr.fit(Xtrain, Ytrain)
# Out:
# LinearRegression()

# %%
# Prediction using training data:

Ytrain_pred = Lr.predict(Xtrain)
Ytrain_pred[:5]
# Out:
# array([12467.53159666, 34739.58565875,  7446.61668192, 10611.52392111,
#        24053.38207569])

# %%
# Prediction using test data: 
Ytest_pred = Lr.predict(Xtest)
Ytest_pred[:5]
# Out:
# array([ 5303.75707909, 10171.31553918, 19442.5867694 , 22426.86249959,
#        21295.38087071])

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# Let's perform some model evaluation using our training and testing data separately.

# %%
# First  we import the seaborn and matplotlibb library for plotting. 
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
# Let's examine the distribution of the predicted values of the training data.
plt.figure(figsize=(14,6))

sns.kdeplot(Ytrain, label = 'Ytrain')
sns.kdeplot(Ytrain_pred, label = 'Ytrain_pred')

plt.legend()

plt.show()
plt.close()

# %% [markdown]
# Figure 1: Plot of predicted values using the training data compared to the training data.

# %% [markdown]
# So far the model seems to be doing well in learning from the training dataset. But what happens when the model encounters new data from the testing dataset? When the model generates new values from the test data, we see the distribution of the predicted values is much different from the actual target values.

# %% [markdown]
# Figur 2: Plot of predicted value using the test data compared to the test data.

# %%
plt.figure(figsize=(14,6))

sns.kdeplot(Ytest, label = 'Ytest')
sns.kdeplot(Ytest_pred, label = 'Ytest_pred')

plt.legend()

plt.show()
plt.close()

# %% [markdown]
# <p>Comparing Figure 1 and Figure 2; it is evident the distribution of the test data in Figure 1 is much better at fitting the data. This difference in Figure 2 is apparent where the ranges are from 5000 to 15 000. This is where the distribution shape is exceptionally different. Let's see if polynomial regression also exhibits a drop in the prediction accuracy when analysing the test dataset.</p>

# %% [markdown]
# <h4>Overfitting</h4>
# <p>Overfitting occurs when the model fits the noise, not the underlying process. Therefore when testing your model using the test-set, your model does not perform as well as it is modelling noise, not the underlying process that generated the relationship. Let's create a degree 5 polynomial model.</p>

# %%
# Determin feature
x = df[['horsepower']]
y = df['price']

# Let's use 55 percent of the data for testing and the rest for training:
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.55, random_state=0)

# We will perform a degree 5 polynomial transformation on the feature 'horse power'.
from sklearn.preprocessing import PolynomialFeatures

pr = PolynomialFeatures(degree=5)
xtrain_pr = pr.fit_transform(xtrain)
xtest_pr = pr.fit_transform(xtest)

# %%
# Now let's create a linear regression model "poly" and train it.
poly = LinearRegression()
poly.fit(xtrain_pr, ytrain)
# Out:
# LinearRegression()

# %%
# We can see the output of our model using the method  "predict." then assign the values to "yhat".
yhat = poly.predict(xtest_pr)

# %%
# Let's take the first five predicted values and compare it to the actual targets. 
print('Predicted values', yhat[:5])
print('Actual values', ytest[:5].values)
# Out:
# Predicted values [ 6440.94874208  7052.12723896 12145.8112617  18349.80805248
#  19588.25443193]
# Actual values [ 6295. 10698. 13860. 13499. 15750.]

# %% [markdown]
# We will use the function "PollyPlot" that we defined at the beginning of the lab to display the training data, testing data, and the predicted function.

# %%
nmax=max([x.values.max()])
nmin=min([x.values.min()])
n=np.arange(nmin, nmax, 0.1)

plt.figure(figsize=(14,6))

plt.plot(xtrain, ytrain, 'ro', label='Training Data')
plt.plot(xtest, ytest, 'go', label='Test Data')
plt.plot(n, poly.predict(pr.fit_transform(n.reshape(-1, 1))), label='Predicted Function')

plt.ylim([-10000, 60000])
plt.ylabel('Price')
plt.legend()

# %% [markdown]
# Figur 4 A polynomial regression model, red dots represent training data, green dots represent test data, and the blue line represents the model prediction.

# %% [markdown]
# We see that the estimated function appears to track the data but around 200 horsepower, the function begins to diverge from the data points.

# %% [markdown]
#  R^2 of the training data:

# %%
poly.score(xtrain_pr, ytrain)
# Out:
# 0.5683022694096513

# %% [markdown]
#  R^2 of the test data:

# %%
poly.score(xtest_pr, ytest)
# Out:
# -38.20956612275342

# %% [markdown]
# We see the R^2 for the training data is 0.568 while the R^2 on the test data was -38.2.  The lower the R^2, the worse the model, a Negative R^2 is a sign of overfitting.

# %% [markdown]
# Let's see how the R^2 changes on the test data for different order polynomials and plot the results:

# %%
Rsqu_test = []

order = [1, 2, 3, 4]
for n in order:
    pr = PolynomialFeatures(degree=n)
    
    xtrain_pr = pr.fit_transform(xtrain)
    
    xtest_pr = pr.fit_transform(xtest)    
    
    poly.fit(xtrain_pr, ytrain)
    
    Rsqu_test.append(poly.score(xtest_pr, ytest))

plt.plot(order, Rsqu_test)
plt.xlabel('order')
plt.ylabel('R^2')
plt.title('R^2 Using Test Data')
plt.text(3, 0.75, 'Maximum R^2 ')
# Out:
# Text(3, 0.75, 'Maximum R^2 ')

# %% [markdown]
# We see the R^2 gradually increases until an order three polynomial is used. Then the  R^2 dramatically decreases at four.

# %% [markdown]
# The following function will be used in the next section; please run the cell.

# %%
def PollyPlot(xtrain, xtest, ytrain, ytest, poly, pr):
    plt.figure(figsize=(14,6))
    
    nmax=max([x.values.max()])
    nmin=min([x.values.min()])
    n=np.arange(nmin, nmax, 0.1)

    plt.figure(figsize=(14,6))

    plt.plot(xtrain, ytrain, 'ro', label='Training Data')
    plt.plot(xtest, ytest, 'go', label='Test Data')
    plt.plot(n, poly.predict(pr.fit_transform(n.reshape(-1, 1))), label='Predicted Function')

    plt.ylim([-10000, 60000])
    plt.ylabel('Price')
    plt.legend()
    
    plt.show()
    plt.close()

# %%
# Determin feature
x = df[['horsepower']]
y = df['price']

def f(order, test_data):
    xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=test_data, random_state=0)
    
    pr = PolynomialFeatures(degree=order)
    
    xtrain_pr = pr.fit_transform(xtrain)
    xtest_pr = pr.fit_transform(xtest)
    
    poly = LinearRegression()
    
    poly.fit(xtrain_pr,ytrain)
    PollyPlot(xtrain, xtest, ytrain, ytest, poly, pr)

# %% [markdown]
# The following interface allows you to experiment with different polynomial orders and different amounts of data.

# %%
from ipywidgets import interact

interact(f, order=(0, 6, 1), test_data=(0.05, 0.95, 0.05))
# Out:
# interactive(children=(IntSlider(value=3, description='order', max=6), FloatSlider(value=0.45, description='tes…
# <function __main__.f(order, test_data)>

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <b>We can perform polynomial transformations with more than one feature. Create a "PolynomialFeatures" object "pr1" of degree two?</b>
# </div>

# %%
# Determine x, y
x = df[['normalized-losses','City-L/100km']]
y = df['price']

# %%
# Create a 'PolinomialFeatures' object:
pr1 = PolynomialFeatures(degree=2)

# %%
# Split data
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.1, random_state=0)

# %%
xtrain_pr = pr1.fit_transform(xtrain)
xtest_pr = pr1.transform(xtest)

# %%
# Now let's create a linear regression model "poly" and train it.
poly = LinearRegression()
poly.fit(xtrain_pr, ytrain)
# Out:
# LinearRegression()

# %%
# Predict
yhat = poly.predict(xtest_pr)
yhat[:5]
# Out:
# array([ 6044.54636256,  8561.0626602 , 10410.36433348, 23326.70383408,
#        18332.02826355])

# %% [markdown]
# Double-click <b>here</b> for the solution.
#
# <!-- The answer is below:
#
# pr1=PolynomialFeatures(degree=2)
#
# -->

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <b>
#  Transform the training and testing samples for the features 'horsepower', 'curb-weight', 'engine-size' and 'highway-mpg'. Hint: use the method "fit_transform"
# ?</b>
# </div>

# %%
# Step 1: Select the Features to Transform (Chọn các đặc trưng bạn muốn biến đổi.)
X = df[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']]
Y = df['price']

# Split data
Xtrain, Xtest, Ytrain, Ytest = train_test_split(X, Y, test_size=0.2, random_state=0)

# %%
# Step 2: Initialize a Preprocessing Object (Khởi tạo đối tượng biến đổi (ví dụ: StandardScaler, PolynomialFeatures))
pr1 = PolynomialFeatures(degree=2)

# %%
# Step 3: Apply Transformation to the Training Set 
        # (Dùng fit_transform trên tập huấn luyện để tính toán tham số và biến đổi dữ liệu huấn luyện.)
Xtrain_pr = pr1.fit_transform(Xtrain)

# %%
# Step 4: Apply Transformation to the Test Set (Áp dụng biến đổi cho tập kiểm tra)
        # Dùng transform trên tập kiểm tra để áp dụng các tham số đã tính từ tập huấn luyện
Xtest_pr = pr1.fit_transform(Xtest)

# %%
# Step 5: Use Transformed Data (Huấn luyện và kiểm tra mô hình với các đặc trưng đã biến đổi)
from sklearn.linear_model import LinearRegression

# %% [markdown]
# Double-click <b>here</b> for the solution.
#
# <!-- The answer is below:
#
# x_train_pr1=pr.fit_transform(x_train[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']])
#
# x_test_pr1=pr.fit_transform(x_test[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']])
#
# -->

# %% [markdown]
# <!-- The answer is below:
#
# x_train_pr1=pr.fit_transform(x_train[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']])
# x_test_pr1=pr.fit_transform(x_test[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']])
#
# -->

# %%
# How many dimensions does the new feature have? Hint: use the attribute "shape"
Xtrain_pr.shape
# Out:
# (160, 15)

# %% [markdown]
# Double-click <b>here</b> for the solution.
#
# <!-- The answer is below:
#
# There are now 15 features: x_train_pr1.shape
#
# -->

# %%
# Create a linear regression model "poly1" and train the object using the method "fit" using the polynomial features?</b>
poly1 = LinearRegression()

# Train the model
poly1.fit(Xtrain_pr, Ytrain)
# Out:
# LinearRegression()

# %% [markdown]
# Double-click <b>here</b> for the solution.
#
# <!-- The answer is below:
#
# poly1=linear_model.LinearRegression().fit(x_train_pr1,y_train)
#
# -->

# %%
# Use the method "predict" to predict an output on the polynomial features

Yhat = poly1.predict(Xtest_pr)

# %%
# Then display the distribution of the predicted output vs the test data?

sns.kdeplot(Ytest, label = 'Actual Test values')
sns.kdeplot(Yhat, label = 'Predicted Test values')

plt.legend()

# %% [markdown]
# Double-click <b>here</b> for the solution.
#
# <!-- The answer is below:
#
# yhat_test1=poly1.predict(x_train_pr1)
# Title='Distribution  Plot of  Predicted Value Using Test Data vs Data Distribution of Test Data'
# DistributionPlot(y_test, yhat_test1, "Actual Values (Test)", "Predicted Values (Test)", Title)
#
# -->

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <b>Use the distribution plot to determine the two regions were the predicted prices are less accurate than the actual prices.</b>
# </div>

# %% [markdown]
# Double-click <b>here</b> for the solution.
#
# <!-- The answer is below:
#
# The predicted value is lower than actual value for cars where the price  $ 10,000 range, conversely the predicted price is larger than the price cost in the $30, 000 to $40,000 range. As such the model is not as accurate in these ranges .
#
# -->
#
# <img src = "https://ibm.box.com/shared/static/c35ipv9zeanu7ynsnppb8gjo2re5ugeg.png" width = 700, align = "center">

# %% [markdown]
# <h2 id="ref3">Part 3: Ridge regression</h2>

# %% [markdown]
#  In this section, we will review Ridge Regression we will see how the parameter Alfa changes the model. Just a note here our test data will be used as validation data.

# %% [markdown]
#  Let's perform a degree two polynomial transformation on our data.

# %%
# Determine features
X = df[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg','normalized-losses','symboling']]
Y = df['price']

# Split data
Xtrain, Xtest, Ytrain, Ytest = train_test_split(X, Y, test_size=0.3, random_state=0)

# %%
pr2 = PolynomialFeatures(degree=2)
Xtrain_pr2 = pr2.fit_transform(Xtrain)
Xtest_pr2 = pr2.fit_transform(Xtest)

# %%
print(Xtrain_pr2.shape)
print(Xtest_pr2.shape)
# Out:
# (140, 28)
# (61, 28)

# %% [markdown]
#  Let's import  <b>Ridge</b>  from the module <b>linear models</b>.

# %%
from sklearn.linear_model import Ridge

# %% [markdown]
# Let's create a Ridge regression object, setting the regularization parameter to 0.1

# %%
RidgeModel = Ridge(alpha=0.1)

# %% [markdown]
# Like regular regression, you can fit the model using the method <b>fit</b>.

# %%
RidgeModel.fit(Xtrain_pr2, Ytrain)
# Out:
# C:\Users\TrinhQuynh\AppData\Local\anaconda3\Lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=8.18509e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# Ridge(alpha=0.1)

# %% [markdown]
#  Similarly, you can obtain a prediction:

# %%
Yhat = RidgeModel.predict(Xtest_pr2)

# %% [markdown]
# Let's compare the first five predicted samples to our test set

# %%
print('predicted:', Yhat[0:4])
print('test set :', Ytest[0:4].values)
# Out:
# predicted: [ 6134.12011264  8544.99790272 21471.61310594 22154.47088759]
# test set : [ 6295. 10698. 13860. 13499.]

# %% [markdown]
# We select the value of Alfa that minimizes the test error, for example, we can use a for loop.

# %%
Rsqu_test = []
Rsqu_train = []
dummy1 = []
ALFA = 10 * np.array(range(0,1000))
for alfa in ALFA:
    RigeModel = Ridge(alpha=alfa) 
    RigeModel.fit(Xtrain_pr2, Ytrain)
    Rsqu_test.append(RigeModel.score(Xtest_pr2, Ytest))
    Rsqu_train.append(RigeModel.score(Xtrain_pr2, Ytrain))

# %% [markdown]
# We can plot out the value of R^2 for different Alphas

# %%
width = 12
height = 10
plt.figure(figsize=(width, height))

plt.plot(ALFA,Rsqu_test, label='validation data  ')
plt.plot(ALFA,Rsqu_train, 'r', label='training Data ')
plt.xlabel('alpha')
plt.ylabel('R^2')
plt.legend()

# %% [markdown]
# Figure 6:The blue line represents the R^2 of the test data, and the red line represents the R^2 of the training data. The x-axis represents the different values of Alfa

# %% [markdown]
# The red line in figure 6 represents the  R^2 of the test data, as Alpha increases the R^2 decreases; therefore as Alfa increases the model performs worse on the test data.  The blue line represents the R^2 on the validation data, as the value for Alfa increases the R^2 decreases.

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
#
# <b>Perform Ridge regression and calculate the R^2 using the polynomial features, use the training data to train the model and test data to test the model. The parameter alpha should be set to  10.
#
# </div>

# %%
# Write your code below:
RidgeModel10 = Ridge(alpha=10)
RidgeModel10.fit(Xtrain_pr2, Ytrain)
Yhat10 = RidgeModel10.predict(Xtest_pr2)

RigeModel.score(Xtest_pr2, Ytest)
# Out:
# 0.42053951412289736

# %% [markdown]
# Double-click <b>here</b> for the solution.
#
# <!-- The answer is below:
#
# RigeModel = Ridge(alpha=0)
# RigeModel.fit(x_train_pr, y_train)
# RigeModel.score(x_test_pr, y_test)
#
# -->

# %% [markdown]
# <h2 id="ref4">Part 4: Grid Search</h2>

# %% [markdown]
# The term Alfa is a hyperparameter, sklearn has the class  <b>GridSearchCV</b> to make the process of finding the best hyperparameter simpler.

# %% [markdown]
# Let's import <b>GridSearchCV</b> from  the module <b>model_selection</b>.

# %%
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# We create a dictionary of parameter values:

# %%
parameters1= [{'alpha': [0.001,0.1,1, 10, 100, 1000, 10000, 100000, 100000]}]
parameters1
# Out:
# [{'alpha': [0.001, 0.1, 1, 10, 100, 1000, 10000, 100000, 100000]}]

# %% [markdown]
# Create a ridge regions object:

# %%
RR=Ridge()
RR
# Out:
# Ridge()

# %% [markdown]
# Create a ridge grid search object

# %%
Grid1 = GridSearchCV(RR, parameters1,cv=4)

# %% [markdown]
# Fit the model

# %%
Grid1.fit(X, Y)
# Out:
# GridSearchCV(cv=4, estimator=Ridge(),
#              param_grid=[{'alpha': [0.001, 0.1, 1, 10, 100, 1000, 10000, 100000,
#                                     100000]}])

# %% [markdown]
# The object finds the best parameter values on the validation data. We can obtain the estimator with the best parameters and assign it to the variable BestRR as follows:

# %%
BestRR=Grid1.best_estimator_
BestRR
# Out:
# Ridge(alpha=10000)

# %% [markdown]
#  We now test our model on the test data

# %%
BestRR.score(Xtest, Ytest)
# Out:
# 0.8372202652558153

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <b>Perform a grid search for the ridge_alpha parameter, then find the best values of the parameters
# </div>

# %%
# Code:
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

# Create pipeline
pipe = Pipeline([('scaler', StandardScaler()),('ridge', Ridge())])

# Cấu hình các siêu tham số để tìm kiếm
parameters2 = {'ridge__alpha': [0.001, 0.1, 1, 10, 100, 1000, 10000, 100000, 100000]}


# Create GridSearchCV
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer, r2_score

Grid2 = GridSearchCV(pipe, parameters2, cv=4)

# Train the model
Grid2.fit(X, Y)

best_model = Grid2.best_estimator_
print("Best model:", best_model)
# Out:
# Best model: Pipeline(steps=[('scaler', StandardScaler()), ('ridge', Ridge(alpha=100))])

# %% [markdown]
# <h1>Thanks for review this notebook!</h1>
